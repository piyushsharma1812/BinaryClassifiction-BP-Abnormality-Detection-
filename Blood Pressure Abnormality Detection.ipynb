# %%
# importing required libraries
import numpy as np # for numerical calculations 
import pandas as pd # for dealing with data 
import matplotlib.pyplot as plt # for visualization
import seaborn as sns # for visualization
import warnings # for ignoring warnings
warnings.filterwarnings('ignore')
color=sns.color_palette()

# %%
# Reading file and taking it as pandas dataframe 
data=pd.read_excel(r'data.xlsx', index=False)
# Lets look first five observation 
data.head()
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
# 2               3                           1                10.79
# 3               4                           0                11.00
# 4               5                           1                14.17
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1        1.0        0
# 1                          0.23   54   33    1        NaN        0
# 2                          0.91   70   49    0        NaN        0
# 3                          0.43   71   50    0        NaN        0
# 4                          0.83   52   19    0        NaN        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                          NaN
# ...

# %%
# Lets describle the data 
data.describe()
# Out:
#        Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# count     2000.000000                 2000.000000          2000.000000
# mean      1000.500000                    0.493500            11.710035
# std        577.494589                    0.500083             2.186701
# min          1.000000                    0.000000             8.100000
# 25%        500.750000                    0.000000            10.147500
# 50%       1000.500000                    0.000000            11.330000
# 75%       1500.250000                    1.000000            12.945000
# max       2000.000000                    1.000000            17.560000
#
#        Genetic_Pedigree_Coefficient          Age          BMI          Sex  \
# count                   1908.000000  2000.000000  2000.000000  2000.000000
# mean                       0.494817    46.558500    30.081500     0.496000
# std                        0.291736    17.107832    11.761208     0.500109
# ...

# %%
# Lets count the null values for each column
data.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
#Attributes Genetic_Pedigree_Coefficient 92
#Pregnancy 1558 
#alcohol_consumption_per_day 242

# %%
# Lets figure out the observation in both the classess how balance the data is 
fig,ax=plt.subplots(1, 2, figsize = (14,5))
sns.countplot(data=data, x='Blood_Pressure_Abnormality', ax=ax[0],palette='Set2')
ax[0].set_xlabel("Abnormility Count \n [0]->No [1]->Yes")
ax[0].set_ylabel("Count")
ax[0].set_title("Blood_Pressure_Abnormality Count")
data['Blood_Pressure_Abnormality'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[1],shadow=True, cmap='Greens')
plt.title("Blood_Pressure_Abnormality")
# Out:
# Text(0.5, 1.0, 'Blood_Pressure_Abnormality')

# %%
# We have both the casses in almost equal numbers

# %% [markdown]
# # Lets perform Feature analysis at individual level

# %%
fig,ax=plt.subplots(1,2,figsize=(14,5))
sns.countplot(x='Sex',data=data,hue='Blood_Pressure_Abnormality',palette='Set1',ax=ax[0])
ax[0].set_xlabel("0 ->Female , 1 ->Male")
data.Sex.value_counts().plot.pie(ax=ax[1],autopct='%1.1f%%',shadow=True, cmap='Reds')
ax[1].set_title("0 ->Female , 1 -> Male")
# Out:
# Text(0.5, 1.0, '0 ->Female , 1 -> Male')

# %%
## So Male are suffering more as compare to female

# %%
#Lets see the relation of Smoking with Blood Pressure Abnormality
fig,ax=plt.subplots(1,2,figsize=(14,5))
sns.countplot(x='Smoking',data=data,hue='Blood_Pressure_Abnormality',palette='Set3',ax=ax[0])
ax[0].set_xlabel("Smoking",size=14)
data.Smoking.value_counts().plot.pie(ax=ax[1],autopct='%1.1f%%',shadow=True,
                                     cmap='Blues')
ax[1].set_title("How Smoking affects",size=12)
ax[1].set_title("0 ->Dont smoke , 1 -> Smoke")
# Out:
# Text(0.5, 1.0, '0 ->Dont smoke , 1 -> Smoke')

# %%
## Primary inference says person who does and does not smoke have almost equal chances for being suffer with abnormility

# %%
# Lets plot Target Blood_Pressure_Abnormality with respect to Predictor Chronic Kidney Disease
fig,ax=plt.subplots(1,2,figsize=(14,5))
sns.countplot(x='Chronic_kidney_disease',data=data,hue='Blood_Pressure_Abnormality',palette='Set1',ax=ax[0])
ax[0].set_xlabel("0 ->Disease Not Present , 1 ->Disease Present")
data.Chronic_kidney_disease.value_counts().plot.pie(ax=ax[1],autopct='%1.1f%%',shadow=True, cmap='Reds')
ax[1].set_title("0 ->Disease Not Present , 1 ->Disease Present")
# Out:
# Text(0.5, 1.0, '0 ->Disease Not Present , 1 ->Disease Present')

# %%
##So cases are more where Person suffering from Chronic Kidney disease is having Blood Pressure abnormality

# %%
# Lets plot for Target Blood Pressure abnormality with respect to the Predictor  "Level_of_Stress"
fig,ax=plt.subplots(1,2,figsize=(14,5))
sns.countplot(x='Level_of_Stress',data=data,hue='Blood_Pressure_Abnormality',palette='Set1',ax=ax[0])
ax[0].set_xlabel("1 -> Stress Level 1 ,2 -> Stress Level 2 ,3 -> Stress Level 3 ")
data.Level_of_Stress.value_counts().plot.pie(ax=ax[1],autopct='%1.1f%%',shadow=True, cmap='Reds')
ax[1].set_title("1 -> Stress Level 1 ,2 -> Stress Level 2 ,3 -> Stress Level 3 ")
# Out:
# Text(0.5, 1.0, '1 -> Stress Level 1 ,2 -> Stress Level 2 ,3 -> Stress Level 3 ')

# %%
## for different level of stress the number of Patients are almost same

# %%
## Lets plot for target Blood_Pressure_Abnormality with respect to predictor "Adrenal_and_thyroid_disorders"
fig,ax=plt.subplots(1,2,figsize=(14,5))
sns.countplot(x='Adrenal_and_thyroid_disorders',data=data,hue='Blood_Pressure_Abnormality',palette='Set1',ax=ax[0])
ax[0].set_xlabel("0 ->Disease Not Present , 1 ->Disease Present")
data.Adrenal_and_thyroid_disorders.value_counts().plot.pie(ax=ax[1],autopct='%1.1f%%',shadow=True, cmap='Reds')
#ax[1].set_title("0 ->Disease Not Present , 1 ->Disease Present")

# %%
# Here Such cases are more where a person suffering from Adrenal and thyroid disorder will have case of Blood Pressure Abnormality

# %% [markdown]
# # As we have explored the categorical variable Let's explore Continuous data now with categorical and ordinal data

# %%
boxplot,factorplot,violinplot,swarmplot

# %%
#Lets consider the variation in hemoglobin level with respect to Sex, Level of stress, smoking and Adrenal thyroid disorders
fig,ax=plt.subplots(2,2,figsize=(14,10))
sns.boxplot(y='Level_of_Hemoglobin',data=data,x='Sex',hue='Blood_Pressure_Abnormality',palette='Set2',ax=ax[0,0])
ax[0,0].set_title("Level_of_Hemoglobin V/S Sex")
sns.boxplot(y='Level_of_Hemoglobin',data=data,x='Level_of_Stress',hue='Blood_Pressure_Abnormality',ax=ax[0,1],palette='Set2')
ax[0,1].set_title("Level_of_Hemoglobin V/S Level_of_Stress ")
sns.boxplot(y='Level_of_Hemoglobin',data=data,x='Smoking',hue='Blood_Pressure_Abnormality',ax=ax[1,0],palette='Set2')
ax[1,0].set_title("Level_of_Hemoglobin V/S Smoking")
sns.boxplot(y='Level_of_Hemoglobin',data=data,x='Adrenal_and_thyroid_disorders',hue='Blood_Pressure_Abnormality',ax=ax[1,1],palette='Set2')
ax[1,1].set_title("Level_of_Hemoglobin V/S Adrenal_and_thyroid_disorders")
# Out:
# Text(0.5, 1.0, 'Level_of_Hemoglobin V/S Adrenal_and_thyroid_disorders')

# %%
# Female have higher hemoglobin level as compared to males outliers are also present which can be treated if they are not crucial

# %%
data.head(2)
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1        1.0        0
# 1                          0.23   54   33    1        NaN        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                          NaN
# 1              26106                     25333                        205.0
#
#    Level_of_Stress  Chronic_kidney_disease  Adrenal_and_thyroid_disorders
# 0                2                       1                              1
# 1                3                       0                              0

# %%
# Genetic_Pedigree_Coefficient with other categorical data
fig,ax=plt.subplots(2,2,figsize=(14,10))
sns.boxplot(y='Genetic_Pedigree_Coefficient',data=data,x='Sex',hue='Blood_Pressure_Abnormality',palette='Set1',ax=ax[0,0])
ax[0,0].set_title("Genetic_Pedigree_Coefficient V/S Sex")
sns.boxplot(y='Genetic_Pedigree_Coefficient',data=data,x='Level_of_Stress',hue='Blood_Pressure_Abnormality',ax=ax[0,1],palette='Set1')
ax[0,1].set_title("Genetic_Pedigree_Coefficient V/S Level_of_Stress")
sns.boxplot(y='Genetic_Pedigree_Coefficient',data=data,x='Smoking',hue='Blood_Pressure_Abnormality',ax=ax[1,0],palette='Set1')
ax[1,0].set_title("Genetic_Pedigree_Coefficient V/S Thal")
sns.boxplot(y='Genetic_Pedigree_Coefficient',data=data,x='Adrenal_and_thyroid_disorders',hue='Blood_Pressure_Abnormality',ax=ax[1,1],palette='Set1')
ax[1,1].set_title("Genetic_Pedigree_Coefficient V/S Adrenal_and_thyroid_disorders")
# Out:
# Text(0.5, 1.0, 'Genetic_Pedigree_Coefficient V/S Adrenal_and_thyroid_disorders')

# %%
# Age with other categorical data
fig,ax=plt.subplots(2,2,figsize=(14,10))
sns.boxplot(y='Physical_activity',data=data,x='Sex',hue='Blood_Pressure_Abnormality',palette='Set1',ax=ax[0,0])
ax[0,0].set_title("Physical_activity V/S Sex")
sns.boxplot(y='Physical_activity',data=data,x='Level_of_Stress',hue='Blood_Pressure_Abnormality',ax=ax[0,1],palette='Set1')
ax[0,1].set_title("Physical_activity V/S Level_of_Stress")
sns.boxplot(y='Physical_activity',data=data,x='Smoking',hue='Blood_Pressure_Abnormality',ax=ax[1,0],palette='Set1')
ax[1,0].set_title("Physical_activity V/S Smoking")
sns.boxplot(y='Physical_activity',data=data,x='Adrenal_and_thyroid_disorders',hue='Blood_Pressure_Abnormality',ax=ax[1,1],palette='Set1')
ax[1,1].set_title("Physical_activity V/S Adrenal_and_thyroid_disorders")
# Out:
# Text(0.5, 1.0, 'Physical_activity V/S Adrenal_and_thyroid_disorders')

# %% [markdown]
# # Now Lets figure out the distribution of each attribute

# %%
data.head(2)
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1        1.0        0
# 1                          0.23   54   33    1        NaN        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                          NaN
# 1              26106                     25333                        205.0
#
#    Level_of_Stress  Chronic_kidney_disease  Adrenal_and_thyroid_disorders
# 0                2                       1                              1
# 1                3                       0                              0

# %%
data.columns
# Out:
# Index(['Patient_Number', 'Blood_Pressure_Abnormality', 'Level_of_Hemoglobin',
#        'Genetic_Pedigree_Coefficient', 'Age', 'BMI', 'Sex', 'Pregnancy',
#        'Smoking', 'Physical_activity', 'salt_content_in_the_diet',
#        'alcohol_consumption_per_day', 'Level_of_Stress',
#        'Chronic_kidney_disease', 'Adrenal_and_thyroid_disorders'],
#       dtype='object')

# %%
predictors=data[[ 'Level_of_Hemoglobin',
        'Age', 'BMI', 'Sex',
       'Smoking', 'Physical_activity', 'salt_content_in_the_diet',
        'Level_of_Stress',
       'Chronic_kidney_disease', 'Adrenal_and_thyroid_disorders']]

# %%
fig,ax=plt.subplots(4,3,figsize=(15,15))
for i in range(10):
    plt.subplot(4,3,i+1)
    sns.distplot(predictors.iloc[:,i],kde=True, color='blue')

# %%
# First curve showing the hemoglobin level is slightly skewed towards right
#

# %% [markdown]
# # Data Cleaning

# %%
#Lets fighure out nnull values present in data
data.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
##first lets imput value in Pregnancy column since we have 50% gender as Male so if rows having gender as male 
##can be filled 0 in Pregnancy column lets make a copy of the original data first

dataN=data

# %%
dataN.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
# Imputing value 0 where ever there exists Sex=1 (Male)
dataN['Pregnancy'] = dataN.apply(
    lambda row: 0 if (np.isnan(row['Pregnancy']) and row['Sex']==1) else row['Pregnancy'],
    axis=1
)

# %%
dataN.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1008
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
dataN.loc[(dataN.Age>60) & (dataN.Sex==0)]
# Out:
#       Level_of_Hemoglobin  Genetic_Pedigree_Coefficient  Age  BMI Sex  \
# 2                   10.79                      0.910000   70   49   0
# 3                   11.00                      0.430000   71   50   0
# 8                   10.88                      0.680000   72   44   0
# 13                  16.42                      0.130000   75   40   0
# 17                  11.60                      0.090000   61   44   0
# ...                   ...                           ...  ...  ...  ..
# 1964                12.19                      0.494817   72   47   0
# 1971                12.53                      0.740000   72   32   0
# 1976                12.07                      0.680000   71   42   0
# 1977                11.16                      0.360000   62   14   0
# 1990                11.21                      0.010000   63   25   0
#
#      Pregnancy Smoking  Physical_activity  salt_content_in_the_diet  \
# ...

# %%
# Since menstrual cycle stops after 40 so its less likely to get pregnant after 40
# Source :https://www.reproductivefacts.org/news-and-publications/patient-fact-sheets-and-booklets/documents/fact-sheets-and-info-booklets/age-and-fertility/
dataN['Pregnancy'] = dataN.apply(
    lambda row: 0 if (np.isnan(row['Pregnancy']) and row['Sex']==0 and row['Age']>=40) else row['Pregnancy'],
    axis=1
)

# %%
dataN.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1008
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
# Since there are 427 values still present that cant be filled using mode since we cant assume that if most of the 
# Womans are pregnant than the rest of woman will also be pregnant in this case lets make a separate category 2 for this 
dataN.Pregnancy.fillna(2,inplace=True)

# %%
# Lets see the values
dataN.isnull().sum()
# Out:
# Patient_Number                     0
# Blood_Pressure_Abnormality         0
# Level_of_Hemoglobin                0
# Genetic_Pedigree_Coefficient      92
# Age                                0
# BMI                                0
# Sex                                0
# Pregnancy                          0
# Smoking                            0
# Physical_activity                  0
# salt_content_in_the_diet           0
# alcohol_consumption_per_day      242
# Level_of_Stress                    0
# Chronic_kidney_disease             0
# Adrenal_and_thyroid_disorders      0
# dtype: int64

# %%
# Now lets fill the values in other column
print(dataN['Genetic_Pedigree_Coefficient'].mean(),
dataN['Genetic_Pedigree_Coefficient'].median(),
dataN['Genetic_Pedigree_Coefficient'].mode())
# Out:
# 0.49481656184486367 0.49 0    0.86
# dtype: float64

# %%
## Since the mean and median both are very close it means the data is having symmetrical distribution and no outlier present

# %%
dataN.Genetic_Pedigree_Coefficient.fillna(dataN['Genetic_Pedigree_Coefficient'].mean(),inplace=True)

# %%
dataN.isnull().sum()
# Out:
# Patient_Number                     0
# Blood_Pressure_Abnormality         0
# Level_of_Hemoglobin                0
# Genetic_Pedigree_Coefficient       0
# Age                                0
# BMI                                0
# Sex                                0
# Pregnancy                          0
# Smoking                            0
# Physical_activity                  0
# salt_content_in_the_diet           0
# alcohol_consumption_per_day      242
# Level_of_Stress                    0
# Chronic_kidney_disease             0
# Adrenal_and_thyroid_disorders      0
# dtype: int64

# %%
# Now lets fill the values in other column
print(dataN['alcohol_consumption_per_day'].mean(),
dataN['alcohol_consumption_per_day'].median(),
dataN['alcohol_consumption_per_day'].mode())
# Out:
# 251.00853242320818 250.0 0    253.0
# dtype: float64

# %%
# Here again the values of mean and median are very close that is the data is having symmetrical distribution so lets
# fill the missing values with mean value of the column
dataN.alcohol_consumption_per_day.fillna(dataN['alcohol_consumption_per_day'].mean(),inplace=True)

# %%
dataN.isnull().sum()
# Out:
# Patient_Number                   0
# Blood_Pressure_Abnormality       0
# Level_of_Hemoglobin              0
# Genetic_Pedigree_Coefficient     0
# Age                              0
# BMI                              0
# Sex                              0
# Pregnancy                        0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# alcohol_consumption_per_day      0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
## Now there is no missing value present in the data

# %%
## So the chances that a person is suffering from Adrenal_and_thyroid_disorders
## will have Blood pressure abnormality is still higher

# %%
# The normal range for hemoglobin is: For men, 13.5 to 17.5 grams per deciliter. For women, 12.0 to 15.5 grams per deciliter
# source : www.mayoclinic.org

# %%
# fig,ax=plt.subplots(1,2,figsize=(14,5))
# sns.countplot(x='Level_of_Hemoglobin',data=data,hue='Blood_Pressure_Abnormality',palette='Set3',ax=ax[0])
# ax[0].set_xlabel("For men, 13.5 to 17.5 grams per deciliter",size=12)
# data.Level_of_Hemoglobin.value_counts().plot.pie(ax=ax[1],autopct='%1.1f%%',shadow=True, explode=[0.1,0],cmap='Oranges')
# ax[1].set_title("For men, 13.5 to 17.5 grams per deciliter",size=12)

# %% [markdown]
# # Now let's work on each feature conversion

# %%
data.columns
# Out:
# Index(['Patient_Number', 'Blood_Pressure_Abnormality', 'Level_of_Hemoglobin',
#        'Genetic_Pedigree_Coefficient', 'Age', 'BMI', 'Sex', 'Pregnancy',
#        'Smoking', 'Physical_activity', 'salt_content_in_the_diet',
#        'alcohol_consumption_per_day', 'Level_of_Stress',
#        'Chronic_kidney_disease', 'Adrenal_and_thyroid_disorders'],
#       dtype='object')

# %%
dataN.Sex=dataN.Sex.astype('category')
dataN.Smoking=dataN.Smoking.astype('category')
dataN.Level_of_Stress=dataN.Level_of_Stress.astype('category')
dataN.Chronic_kidney_disease=dataN.Chronic_kidney_disease.astype('category')
dataN.Adrenal_and_thyroid_disorders=dataN.Adrenal_and_thyroid_disorders.astype('category')
dataN.Pregnancy=dataN.Pregnancy.astype('category')

# %%
#Lets Make other copy of dataN
dataNN=dataN

# %%
#Taking the Target column and deleting Patient number(since its just a count) and Blood pressure abnormility 
data_label=dataNN['Blood_Pressure_Abnormality']
del dataNN['Blood_Pressure_Abnormality']
del dataNN['Patient_Number']
data_label=pd.DataFrame(data_label)

# %%
dataNN.columns
# Out:
# Index(['Level_of_Hemoglobin', 'Genetic_Pedigree_Coefficient', 'Age', 'BMI',
#        'Sex', 'Pregnancy', 'Smoking', 'Physical_activity',
#        'salt_content_in_the_diet', 'alcohol_consumption_per_day',
#        'Level_of_Stress', 'Chronic_kidney_disease',
#        'Adrenal_and_thyroid_disorders'],
#       dtype='object')

# %%
# Droping header from dataframe and creating dummies for categorical variables  
dataNN=pd.get_dummies(dataNN,drop_first=True)
dataNN.head(),data_label.head()
# Out:
# (   Level_of_Hemoglobin  Genetic_Pedigree_Coefficient  Age  BMI  \
#  0                11.28                          0.90   34   23
#  1                 9.75                          0.23   54   33
#  2                10.79                          0.91   70   49
#  3                11.00                          0.43   71   50
#  4                14.17                          0.83   52   19
#
#     Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
#  0              45961                     48071                   251.008532
#  1              26106                     25333                   205.000000
#  2               9995                     29465                    67.000000
#  3              10635                      7439                   242.000000
#  4              15619                     49644                   397.000000
#
#     Sex_1  Pregnancy_1.0  Pregnancy_2.0  Smoking_1  Level_of_Stress_2  \
# ...

# %% [markdown]
# # Normalization (To get value b/w 0 and 1)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
data_scaled=MinMaxScaler().fit_transform(dataNN)
data_scaled=pd.DataFrame(data=data_scaled, columns=dataNN.columns)

# %%
data_scaled.head(1)
# Out:
#    Level_of_Hemoglobin  Genetic_Pedigree_Coefficient       Age    BMI  \
# 0             0.336152                           0.9  0.280702  0.325
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0           0.918565                  0.961865                     0.503023
#
#    Sex_1  Pregnancy_1.0  Pregnancy_2.0  Smoking_1  Level_of_Stress_2  \
# 0    1.0            1.0            0.0        0.0                1.0
#
#    Level_of_Stress_3  Chronic_kidney_disease_1  \
# 0                0.0                       1.0
#
#    Adrenal_and_thyroid_disorders_1
# 0                              1.0

# %%
##Now all the values of data set are in range of 0 and 1

# %% [markdown]
# # Predictive Modeling

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest = train_test_split(data_scaled, data_label, test_size=0.20,
                                             stratify=data_label,random_state=9154)

# %%
# Importing ML  libraries 
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Evaluation metrics 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# %%
# Defining cross validation function
def CrossVal(dataX,dataY,mode,cv=3):
    score=cross_val_score(mode,dataX , dataY, cv=cv, scoring='accuracy')
    return(np.mean(score))

# %%
## Function to plot ROC and Precision Recall Curve
def plotting(true,pred):
    fig,ax=plt.subplots(1,2,figsize=(10,5))
    precision,recall,threshold = precision_recall_curve(true,pred[:,1])
    ax[0].plot(recall,precision,'g--')
    ax[0].set_xlabel('Recall')
    ax[0].set_ylabel('Precision')
    ax[0].set_title("Average Precision Score : {}".format(average_precision_score(true,pred[:,1])))
    fpr,tpr,threshold = roc_curve(true,pred[:,1])
    ax[1].plot(fpr,tpr)
    ax[1].set_title("AUC Score is: {}".format(auc(fpr,tpr)))
    ax[1].plot([0,1],[0,1],'k--')
    ax[1].set_xlabel('False Positive Rate')
    ax[1].set_ylabel('True Positive Rate')

# %%
## Stochastic gradient descent 
#Lets set tollerence=1e-10 minimum is better, loss as logloss and regularization =L2  and learning rate be 0.01
sgd=SGDClassifier(tol=1e-10, random_state=23,loss='log', penalty= "l2", alpha=0.01)
score_sgd=CrossVal(Xtrain,Ytrain,sgd)
print("Accuracy is : ",score_sgd)
sgd.fit(Xtrain,Ytrain)
plotting(Ytest,sgd.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,sgd.predict(Xtest)), annot= True, cmap='Oranges',fmt='d')
sgd_f1=f1_score(Ytest,sgd.predict(Xtest))
plt.title('F1 Score = {}'.format(sgd_f1))
# Out:
# Accuracy is :  0.7262380748267292
# Text(0.5, 1, 'F1 Score = 0.6831683168316831')

# %%
# K Nearest Neighbors
k=KNeighborsClassifier(algorithm='auto',n_neighbors= 5)
score_k=CrossVal(Xtrain,Ytrain,k)
print("Accuracy is : ",score_k)
k.fit(Xtrain,Ytrain)
plotting(Ytest,k.predict_proba(Xtest))


fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,k.predict(Xtest)), annot= True, cmap='Reds',fmt='d')
k_f1=f1_score(Ytest,k.predict(Xtest))
plt.title('F1 Score = {}'.format(k_f1))
# Out:
# Accuracy is :  0.7106196991096964
# Text(0.5, 1, 'F1 Score = 0.6444444444444445')

# %%
# Logistic Regression lets tollerence value as 1e-10 since we want it minimum 
# Lets put class_weight=balanced it basically means replicating the smaller class until you have as many samples as in the larger one, 
lr=LogisticRegression(class_weight='auto', tol=1e-10)
score_lr=CrossVal(Xtrain,Ytrain,lr)
print("Accuracy is : ",score_lr)
lr.fit(Xtrain,Ytrain)
plotting(Ytest,lr.predict_proba(Xtest))


fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,lr.predict(Xtest)), annot= True, cmap='Greens',fmt='d')
lr_f1=f1_score(Ytest,lr.predict(Xtest))
plt.title('F1 Score = {}'.format(lr_f1))
# Out:
# Accuracy is :  0.7206083858591396
# Text(0.5, 1, 'F1 Score = 0.6753246753246753')

# %%
# There was not much difference in accuracy with weight='balanced'

# %%
# Decision Tree
dtc=DecisionTreeClassifier(max_depth=6)
score_dtc=CrossVal(Xtrain,Ytrain,dtc)
print("Accuracy is : ",score_dtc)
dtc.fit(Xtrain,Ytrain)
plotting(Ytest,dtc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,dtc.predict(Xtest)), annot= True, cmap='Blues',fmt='d')

dtc_f1=f1_score(Ytest,dtc.predict(Xtest))
plt.title('F1 Score = {}'.format(dtc_f1))
# Out:
# Accuracy is :  0.8668877786444243
# Text(0.5, 1, 'F1 Score = 0.8518518518518519')

# %%
# Here in this case decision tree is working well for classifying

# %%
# Support Vector Machine
svc=SVC(C=0.2,probability=True,kernel='rbf',gamma=0.1)
score_svc=CrossVal(Xtrain,Ytrain,svc)
print("Accuracy is : ",score_svc)
svc.fit(Xtrain,Ytrain)
plotting(Ytest,svc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,svc.predict(Xtest)), annot= True, cmap='Greys',fmt='d')
svc_f1=f1_score(Ytest,svc.predict(Xtest))
plt.title('F1 Score = {}'.format(svc_f1))
# Out:
# Accuracy is :  0.7193587752645029
# Text(0.5, 1, 'F1 Score = 0.6995073891625616')

# %%
# SVM is not performing well as compared to Decision tree

# %%
#Random Forest
rf=RandomForestClassifier(n_estimators=75, n_jobs=-1, random_state=97)
score_rf= CrossVal(Xtrain,Ytrain,rf)
print('Accuracy is:',score_rf)
rf.fit(Xtrain,Ytrain)
plotting(Ytest,rf.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,rf.predict(Xtest)), annot= True, cmap='Oranges',fmt='d')

rf_f1=f1_score(Ytest,rf.predict(Xtest))
plt.title('F1 Score = {}'.format(rf_f1))
# Out:
# Accuracy is: 0.8725057561725142
# Text(0.5, 1, 'F1 Score = 0.8711340206185567')

# %%
# When no. of trees are increased F1 score and AUC also increase  but later there is not much difference

# %%
# Extra Tree classifier
etc=ExtraTreesClassifier(n_estimators=200, n_jobs=-1, random_state=2)
score_etc= CrossVal(Xtrain,Ytrain,etc)
print('Accuracy is:',score_etc)
etc.fit(Xtrain,Ytrain)
plotting(Ytest,etc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,etc.predict(Xtest)), annot= True, cmap='Greens',fmt='d')

etc_f1=f1_score(Ytest,etc.predict(Xtest))
plt.title('F1 Score = {}'.format(etc_f1))
# Out:
# Accuracy is: 0.8399983135527119
# Text(0.5, 1, 'F1 Score = 0.8210526315789474')

# %%
#Performance is good but not as good as RF

# %%
#Adaboost Algorithm
abc=AdaBoostClassifier(sgd,n_estimators=100, random_state=343, learning_rate=0.012)
score_ada= CrossVal(Xtrain,Ytrain,abc)
print('Accuracy is:',score_ada)
abc.fit(Xtrain,Ytrain)
plotting(Ytest,abc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,abc.predict(Xtest)), annot= True, cmap='Reds',fmt='d')

abc_f1=f1_score(Ytest,abc.predict(Xtest))
plt.title('F1 Score = {}'.format(abc_f1))
# Out:
# Accuracy is: 0.7062290804411934
# Text(0.5, 1, 'F1 Score = 0.7186147186147186')

# %%
# Gradient Boosting
gbc=GradientBoostingClassifier(n_estimators=100, random_state=43, learning_rate = 0.01)
score_gbc= CrossVal(Xtrain,Ytrain,gbc)
print('Accuracy is:',score_gbc)
gbc.fit(Xtrain,Ytrain)
plotting(Ytest,gbc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,gbc.predict(Xtest)), annot= True, cmap='Blues',fmt='d')

gbc_f1=f1_score(Ytest,gbc.predict(Xtest))
plt.title('F1 Score = {}'.format(gbc_f1))
# Out:
# Accuracy is: 0.8499916848779551
# Text(0.5, 1, 'F1 Score = 0.86')

# %%
# Bagging Classifier
bc=BaggingClassifier(lr,max_samples=23, bootstrap=True, n_jobs= -1)
score_bc= CrossVal(Xtrain,Ytrain,bc)
print('Accuracy is:',score_bc)
bc.fit(Xtrain,Ytrain)
plotting(Ytest,bc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,bc.predict(Xtest)), annot= True, cmap='Greys')

bc_f1=f1_score(Ytest,bc.predict(Xtest))
plt.title('F1 Score = {}'.format(bc_f1))
# Out:
# Accuracy is: 0.6881126546788372
# Text(0.5, 1, 'F1 Score = 0.6966292134831461')

# %%
# Lets figure out the importance of feature which helped in prediction 
fig= plt.figure(figsize=(10,10))
important=pd.Series(rf.feature_importances_, index=Xtrain.columns)
sns.set_style('whitegrid')
important.sort_values().plot.barh()
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
# Plotting accuracy of different models that we used 
model_accuracy = pd.Series(data=[score_sgd, score_k, score_lr, score_dtc, score_svc, score_rf, score_etc, 
                           score_ada, score_gbc, score_bc], 
                           index=['Stochastic GD','KNN','logistic Regression','decision tree', 'SVM', 'Random Forest',
                            'Extra Tree', 'Ada Boost' , 'Gradient Boost','Bagging Classfier'])
fig= plt.figure(figsize=(8,8))
model_accuracy.sort_values().plot.barh()
plt.title('Model Accracy')
# Out:
# Text(0.5, 1.0, 'Model Accracy')

# %%
# Since accuracy is not a good measure lets see the other metrics also
model_f1_score = pd.Series(data=[sgd_f1, k_f1, lr_f1, dtc_f1, svc_f1, rf_f1, etc_f1, 
                           abc_f1, gbc_f1, bc_f1], 
                           index=['Stochastic GD','KNN','logistic Regression','decision tree', 'SVM', 'Random Forest',
                                'Extra Tree', 'Ada Boost' , 'Gradient Boost', 'Bagging Classfier'])
fig= plt.figure(figsize=(8,8))
model_f1_score.sort_values().plot.barh()
plt.title('Model F1 Score Comparison')
# Out:
# Text(0.5, 1.0, 'Model F1 Score Comparison')

# %%
# Since the column pregnancy was only 25% filled applied different techniques to imput it 
#some part of it filled 0 considering gender column so 50% of values got filled for remaining 505 missing values applied 
#two different techniques in the first one filled the values as 0 where ever the age was more than 51 (Average age of Menopause)
#and remaining values filled with a different category and trained the models 
#in second approach remaining 50% values directly repalced with a different category and trained the model 
#seeing the feature importance in both the approaches it appeared that weightage of this feature was less

# %%
## Out of all the models random forest is performing well 
#now lets search for its hyperparameters
#Random Forest
rf=RandomForestClassifier(n_estimators=75, n_jobs=-1, random_state=97)
score_rf= CrossVal(Xtrain,Ytrain,rf)
print('Accuracy is:',score_rf)
rf.fit(Xtrain,Ytrain)
plotting(Ytest,rf.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,rf.predict(Xtest)), annot= True, cmap='Oranges',fmt='d')

rf_f1=f1_score(Ytest,rf.predict(Xtest))
plt.title('F1 Score = {}'.format(rf_f1))
# Out:
# Accuracy is: 0.8725057561725142
# Text(0.5, 1, 'F1 Score = 0.8711340206185567')

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
# Create a based model
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %% [markdown]
# # Fit the grid search to the data
# grid_search.fit(Xtrain,Ytrain)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 80,
#  'max_features': 3,
#  'min_samples_leaf': 5,
#  'min_samples_split': 12,
#  'n_estimators': 1000}

# %%
rf=RandomForestClassifier(bootstrap= True,
 max_depth= 80,
 max_features= 3,
 min_samples_leaf= 5,
 min_samples_split= 12,
 n_estimators= 1000, n_jobs=-1, random_state=97)
score_rf= CrossVal(Xtrain,Ytrain,rf)
print('Accuracy is:',score_rf)
rf.fit(Xtrain,Ytrain)
plotting(Ytest,rf.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,rf.predict(Xtest)), annot= True, cmap='Oranges',fmt='d')

rf_f1=f1_score(Ytest,rf.predict(Xtest))
plt.title('F1 Score = {}'.format(rf_f1))
# Out:
# Accuracy is: 0.8793827134468405
# Text(0.5, 1, 'F1 Score = 0.8826530612244897')

# %% [markdown]
# So the above random forest model is the final model with slightly optimized hyperparameters which is yielding good results for
# True Negative so there is a slight improvization
#
# Steps Taken:
# At the very first observed the data and its spread
# checked counts of abnormility cases with respect to the different predictors using histograms and pie chart
# then plotted box plot for differnt continuous variable to assess the presence of outlier.
# In some the variable outlier was present
#
# Attribute Pregnancy had at first 1558 missing values then it was filled considering the gender column resultant had 1008 missing value which could be filled by considering age column with the help of some online sources
# when we consider age of Menopause = 40 then more than 75% data could be imputed in the column
# if we consider the average age of menopause it increased slightly but when we put age =60 then there were 427 values which remained NaN
#
# then went for other attributes having missing values
# since the value of thier mean and median was almost same that could be filled with any of the values mean or median.
# once the data had no missing values
# the data was preprocessed further with techniques like normalization and scaling. since  the data had no skewness further distribution transformation was not required.
#
# once the data was prepared it splitted into train and test with 20 percent for test and 80 percent for training
# then differnt algorithms applied and performed cross validation
# Other algorithms (Logistic regression and SVM ,Knn )didn't performed well tree based algorithms outperformed
# Random forest with highest F1 score among all other algorithms was hypertuned using grid search. Which yield AUC=93% and 90% precision than previous 92% and 87% respectively
#
# since random forest does not affects with outliers as compared to other algorithms like logistic regression its an added advantage to use this algorithms here in this case we are not sure how outlier removal will affect the data
